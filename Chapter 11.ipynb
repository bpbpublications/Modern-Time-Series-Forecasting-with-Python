# %% [markdown]
# # Book - Modern Time Series Forecasting with Python
#
# ## Chapter 11 - Advanced Deep Learning Architectures and Multivariate Forecasting
#
#
# ### Python version 3.8
#
# ### Libraries version
# * matplotlib: 3.7.1
# * pandas: 2.0.3
# * numpy: 1.23.5
# * sklearn: 1.3.2
# * seaborn: 0.13.2
# * statsmodels: 0.14.1
# * tensorflow: 2.12.0
# * keras: 2.12.0

# %%
print("This is theoretical Chapter, so no code")
# Out:
# This is theoretical Chapter, so no code
